# %%
import pandas as pd
ind = pd.read_csv("data/ind30_m_vw_rets.csv", header=0,index_col=0,parse_dates=True)/100
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_2704\1876279929.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ind = pd.read_csv("data/ind30_m_vw_rets.csv", header=0,index_col=0,parse_dates=True)/100

# %%
ind.head
# Out:
# <bound method NDFrame.head of          Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 192607  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 192608  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 192609  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 192610 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 192611  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 201808 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 201809 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 201810  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 201811  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 201812 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
#          Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# ...

# %%
ind.index = pd.to_datetime(ind.index,format="%Y%m").to_period("M")

# %%
ind.head
# Out:
# <bound method NDFrame.head of           Food    Beer    Smoke   Games   Books   Hshld   Clths   Hlth   \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 2018-08 -0.0038 -0.0186 -0.0543  0.0289 -0.0447  0.0254  0.0526  0.0446
# 2018-09 -0.0032  0.0019  0.0537 -0.0009 -0.0221  0.0107  0.0130  0.0199
# 2018-10  0.0102 -0.0157  0.0790 -0.1596 -0.0666 -0.0051 -0.1014 -0.0884
# 2018-11  0.0272  0.0579 -0.0843 -0.0065  0.0325  0.0644 -0.0099  0.0632
# 2018-12 -0.0973 -0.0969 -0.1580 -0.0824 -0.1535 -0.0557 -0.0728 -0.0840
#
# ...

# %%
ind.columns = ind.columns.str.strip()

# %%
ind.columns
# Out:
# Index(['Food', 'Beer', 'Smoke', 'Games', 'Books', 'Hshld', 'Clths', 'Hlth',
#        'Chems', 'Txtls', 'Cnstr', 'Steel', 'FabPr', 'ElcEq', 'Autos', 'Carry',
#        'Mines', 'Coal', 'Oil', 'Util', 'Telcm', 'Servs', 'BusEq', 'Paper',
#        'Trans', 'Whlsl', 'Rtail', 'Meals', 'Fin', 'Other'],
#       dtype='object')

# %%
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
import my_modules as mm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = mm.get_ind_returns()
# Out:
# C:\Users\Administrator\Investment_management\my_modules.py:58: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   ind = pd.read_csv("data/ind30_m_vw_rets.csv", header=0,index_col=0,parse_dates=True)/100

# %%
ind.head()
# Out:
#            Food    Beer   Smoke   Games   Books   Hshld   Clths    Hlth  \
# 1926-07  0.0056 -0.0519  0.0129  0.0293  0.1097 -0.0048  0.0808  0.0177
# 1926-08  0.0259  0.2703  0.0650  0.0055  0.1001 -0.0358 -0.0251  0.0425
# 1926-09  0.0116  0.0402  0.0126  0.0658 -0.0099  0.0073 -0.0051  0.0069
# 1926-10 -0.0306 -0.0331  0.0106 -0.0476  0.0947 -0.0468  0.0012 -0.0057
# 1926-11  0.0635  0.0729  0.0455  0.0166 -0.0580 -0.0054  0.0187  0.0542
#
#           Chems   Txtls  ...   Telcm   Servs   BusEq   Paper   Trans   Whlsl  \
# 1926-07  0.0814  0.0039  ...  0.0083  0.0922  0.0206  0.0770  0.0193 -0.2379
# 1926-08  0.0550  0.0814  ...  0.0217  0.0202  0.0439 -0.0238  0.0488  0.0539
# 1926-09  0.0533  0.0231  ...  0.0241  0.0225  0.0019 -0.0554  0.0005 -0.0787
# 1926-10 -0.0476  0.0100  ... -0.0011 -0.0200 -0.0109 -0.0508 -0.0264 -0.1538
# 1926-11  0.0520  0.0311  ...  0.0163  0.0377  0.0364  0.0384  0.0160  0.0467
#
#           Rtail   Meals     Fin   Other
# ...

# %%
ind.shape
# Out:
# (1110, 30)

# %%
mm.drawdown(ind["Food"])["Drawdowns"].plot.line(figsize=(12,6))
plt.show()

# %%
mm.var_gaussian(ind, modified=True).sort_values().plot.bar()
plt.show()

# %%
mm.sharpe_ratio(ind["2000":],0.03,12).sort_values().plot.bar()
plt.show()

# %%
er = mm.annualize_rets(ind["1996":"2000"],12)

# %%
er.plot.bar()
plt.show()

# %%
cov = ind["1996":"2000"].cov()

# %%
cov
# Out:
#            Food      Beer     Smoke     Games     Books     Hshld     Clths  \
# Food   0.002609  0.002379  0.002061  0.000846  0.001035  0.001374  0.001733
# Beer   0.002379  0.005264  0.001359  0.001348  0.000865  0.002804  0.001704
# Smoke  0.002061  0.001359  0.008349  0.000379 -0.000128  0.001167  0.000950
# Games  0.000846  0.001348  0.000379  0.003773  0.001726  0.001206  0.002189
# Books  0.001035  0.000865 -0.000128  0.001726  0.002612  0.001025  0.002361
# Hshld  0.001374  0.002804  0.001167  0.001206  0.001025  0.003300  0.001320
# Clths  0.001733  0.001704  0.000950  0.002189  0.002361  0.001320  0.005655
# Hlth   0.001230  0.001955  0.001038  0.001433  0.000758  0.001473  0.000834
# Chems  0.001414  0.001460  0.000853  0.001775  0.001731  0.001413  0.002932
# Txtls  0.001216  0.002005  0.000779  0.001422  0.001459  0.001364  0.002472
# Cnstr  0.001487  0.002268  0.001446  0.002013  0.001753  0.002080  0.002937
# ...

# %%
def portfolio_return(weights, returns):
    return weights.T@ returns

def portfolio_vol(weights, covmat):
    returns (weights.T@covmat@weights)**0.5

# %%
l = ["Food", "Beer", "Smoke", "Coal"]
er[l]
# Out:
# Food     0.116799
# Beer     0.141126
# Smoke    0.107830
# Coal     0.414689
# dtype: float64

# %%
cov.loc[l,l]
# Out:
#            Food      Beer     Smoke      Coal
# Food   0.002609  0.002379  0.002061  0.000027
# Beer   0.002379  0.005264  0.001359  0.001728
# Smoke  0.002061  0.001359  0.008349 -0.000733
# Coal   0.000027  0.001728 -0.000733  0.018641

# %%
import numpy as np
weights = np.repeat(1/4,4)
mm.portfolio_return(weights,er[l])
# Out:
# 0.19511097196038385

# %%
l = ['Games','Fin']
n_points = 20
weights = [np.array([w,1-w]) for w in np.linspace(0,1,n_points)]
weights
# Out:
# [array([0., 1.]),
#  array([0.05263158, 0.94736842]),
#  array([0.10526316, 0.89473684]),
#  array([0.15789474, 0.84210526]),
#  array([0.21052632, 0.78947368]),
#  array([0.26315789, 0.73684211]),
#  array([0.31578947, 0.68421053]),
#  array([0.36842105, 0.63157895]),
#  array([0.42105263, 0.57894737]),
#  array([0.47368421, 0.52631579]),
#  array([0.52631579, 0.47368421]),
#  array([0.57894737, 0.42105263]),
#  array([0.63157895, 0.36842105]),
#  array([0.68421053, 0.31578947]),
#  array([0.73684211, 0.26315789]),
#  array([0.78947368, 0.21052632]),
#  array([0.84210526, 0.15789474]),
#  array([0.89473684, 0.10526316]),
#  array([0.94736842, 0.05263158]),
#  array([1., 0.])]

# %%
rets = [mm.portfolio_return(w,er[l]) for w in weights]
vols = [mm.portfolio_return(w,cov.loc[l,l]) for w in weights]
import pandas as pd
ef = pd.DataFrame({"R":rets, "Vol":vols})
ef.plot.scatter(x="Vol",y="R")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:248, in _coerce_method.<locals>.wrapper(self)
#     247     return converter(self.iloc[0])
# --> 248 raise TypeError(f"cannot convert the series to {converter}")
#
# TypeError: cannot convert the series to <class 'float'>
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 5
#       3 import pandas as pd
#       4 ef = pd.DataFrame({"R":rets, "Vol":vols})
# ----> 5 ef.plot.scatter(x="Vol",y="R")
#       6 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1748, in PlotAccessor.scatter(self, x, y, s, c, **kwargs)
#    1660 def scatter(
#    1661     self,
#    1662     x: Hashable,
#    (...)
#    1666     **kwargs,
# ...

# %%
l = ['Smoke',"Games","Fin",'Coal']
mm.plot_ef2(25,er[l], cov.loc[l,l])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 l = ['Smoke',"Games","Fin",'Coal']
# ----> 2 mm.plot_ef2(25,er[l], cov.loc[l,l])
#       3 plt.show()
#
# AttributeError: module 'my_modules' has no attribute 'plot_ef2'

# %%
w15 = mm.minimise_vol(0.15,er[l],cov.loc[l,l])
vol15 = mm.portfolio_vol(w15,cov.loc[l,l])
vol15
w15
# Out:
# array([0.24152012, 0.39842497, 0.27457601, 0.0854789 ])

# %%
mm.plot_ef(25,er[l],cov.loc[l,l])
# Out:
# <Axes: xlabel='Volatility'>
